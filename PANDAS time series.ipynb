# %% [markdown]
# **PANDAS TIME SERIES**

# %% [markdown]
# We can find out the data within a certain range of dates and time
#
# by using pandas module named times series .

# %% [markdown]
# --Equivalent to date time python package
#
# -- used to deal with date time
#
# --Complex op on date time can be done .

# %% [markdown]
# **TIME STAMP**
#
# 21-Jan-2021
#
# 21-January-2021
#
#
# 21-01-2021
#
#  21-01-2021 30:12:11

# %%
data = '15-January-2023'
type(data)
# Out:
# str

# %% [markdown]
# ##to_datetime

# %%
import pandas as pd
dt = pd.to_datetime(data,format='%d-%B-%Y')
dt
# Out:
# Timestamp('2023-01-15 00:00:00')

# %%
type(dt)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# %d 01,22,23

# %%
# %B January,march
# %b Jan,mar
# %m int (month in integer)

# %%
# %Y 2023,2024
# %y 23,24
# %H----24Hr
# %I----12hr
# %M - minute
# %S- seconds

# %%
date = ['2023-11-23 2:30:00 PM', 'jan 6,2024 20:11:00', '11/02/11','2024.22,11','2023/05/12','20240512']
import pandas as pd
date_time = pd.to_datetime(date)
date_time
# Out:
# <ipython-input-7-b0b405978a01>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   date_time = pd.to_datetime(date)
# DatetimeIndex(['2023-11-23 14:30:00', '2024-01-06 20:11:00',
#                '2011-11-02 00:00:00', '2024-11-01 00:00:00',
#                '2023-05-12 00:00:00', '2024-05-12 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
import pandas as pd
date = '31-jan-20'
date_time = pd.to_datetime(date)
print(date_time)
print(date_time.day)
print(date_time.week)
print(date_time.day_of_week)
print(date_time.day_of_year)
print(date_time.minute)
print(date_time.is_leap_year)
print(date_time.is_month_end)
print(date_time.is_month_start)
print(date_time.month)
print(date_time.quarter)
# Out:
# 2020-01-31 00:00:00
# 31
# 5
# 4
# 31
# 0
# True
# True
# False
# 1
# 1
